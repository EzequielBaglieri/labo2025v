# %% [markdown]
# <a href="https://colab.research.google.com/github/EzequielBaglieri/labo2025v/blob/main/src/ensembles/594_TareaHogar_05_Exp5942_HiPeRMODIF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 06:18:03 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660356 35.3 1454488    77.7 1454488  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5942
PARAM$semilla_primigenia <- 700001

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 3000, # ANTES ERA 1200
  early_stopping_rounds= 200, #LO SAQUE DEL 470 DE LA CLASE 5
  learning_rate= 0.02,
  feature_fraction= 0.55, # ANTES ERA 0.5
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 150L, upper= 3000L),    #ANTES ERA 8 Y 2048
  makeNumericParam("learning_rate", lower= 0.0045, upper= 0.1),     #ANTES ERA 0.01 Y 0.3
  makeNumericParam("feature_fraction", lower= 0.45, upper= 0.65), #ANTES ERA 0.1 Y 1
  makeIntegerParam("num_leaves", lower= 8L, upper= 1024L),        #ANTES ERA 8 Y 2048
  makeIntegerParam("min_data_in_leaf", lower= 155L, upper= 550L),   #ANTES ERA 1 Y 8000L
  # ****************************************
  # Nuevos Parámetros Añadidos
  # ****************************************
  makeNumericParam("bagging_fraction", lower= 0.5, upper= 1.0), # Control de submuestreo de filas (Bagging)
  makeIntegerParam("bagging_freq", lower= 0L, upper= 7L),       # Frecuencia del Bagging
  makeNumericParam("scale_pos_weight", lower= 1.0, upper= 30.0) # Control de desbalance de clases
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 80 # iteraciones bayesianas // ORIGINAL 30 // OTROS EXP 70

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83523
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Tue Nov 04 06:29:34 PM 2025 AUC 0.93076695524263
#
# [mbo] 29: num_iterations=523; learning_rate=0.00935; feature_fraction=0.573; num_leaves=133; min_data_in_leaf=424; bagging_fraction=0.804; bagging_freq=2; scale_pos_weight=1.06 : y = 0.931 : 119.2 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:31:33 PM 2025 AUC 0.930306728951107
#
# [mbo] 30: num_iterations=1362; learning_rate=0.0129; feature_fraction=0.606; num_leaves=506; min_data_in_leaf=448; bagging_fraction=0.996; bagging_freq=1; scale_pos_weight=18 : y = 0.93 : 118.3 secs : infill_ei
#
# Tue Nov 04 06:32:04 PM 2025 AUC 0.926312096534689
#
# [mbo] 31: num_iterations=159; learning_rate=0.0116; feature_fraction=0.575; num_leaves=638; min_data_in_leaf=421; bagging_fraction=0.726; bagging_freq=0; scale_pos_weight=1.36 : y = 0.926 : 31.3 secs : infill_ei
#
# Tue Nov 04 06:33:01 PM 2025 AUC 0.929087553831553
#
# [mbo] 32: num_iterations=536; learning_rate=0.011; feature_fraction=0.576; num_leaves=12; min_data_in_leaf=467; bagging_fraction=0.806; bagging_freq=0; scale_pos_weight=6.98 : y = 0.929 : 55.6 secs : infill_ei
#
# Tue Nov 04 06:34:46 PM 2025 AUC 0.929372684139803
#
# [mbo] 33: num_iterations=668; learning_rate=0.0102; feature_fraction=0.632; num_leaves=842; min_data_in_leaf=550; bagging_fraction=0.942; bagging_freq=0; scale_pos_weight=8.06 : y = 0.929 : 104.5 secs : infill_ei
#
# Tue Nov 04 06:37:29 PM 2025 AUC 0.930858514166793
#
# [mbo] 34: num_iterations=1673; learning_rate=0.00995; feature_fraction=0.617; num_leaves=656; min_data_in_leaf=447; bagging_fraction=0.962; bagging_freq=0; scale_pos_weight=17.9 : y = 0.931 : 162.5 secs : infill_ei
#
# Tue Nov 04 06:39:31 PM 2025 AUC 0.930661340431325
#
# [mbo] 35: num_iterations=1618; learning_rate=0.0151; feature_fraction=0.581; num_leaves=128; min_data_in_leaf=501; bagging_fraction=0.939; bagging_freq=0; scale_pos_weight=16.8 : y = 0.931 : 121.5 secs : infill_ei
#
# Tue Nov 04 06:45:55 PM 2025 AUC 0.931493244732446
#
# [mbo] 36: num_iterations=1988; learning_rate=0.00492; feature_fraction=0.596; num_leaves=668; min_data_in_leaf=489; bagging_fraction=0.949; bagging_freq=2; scale_pos_weight=16.6 : y = 0.931 : 382.4 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:50:32 PM 2025 AUC 0.930557694362951
#
# [mbo] 37: num_iterations=1725; learning_rate=0.0061; feature_fraction=0.626; num_leaves=889; min_data_in_leaf=500; bagging_fraction=0.977; bagging_freq=2; scale_pos_weight=14 : y = 0.931 : 277.2 secs : infill_ei
#
# Tue Nov 04 06:54:50 PM 2025 AUC 0.931099730369063
#
# [mbo] 38: num_iterations=2138; learning_rate=0.00494; feature_fraction=0.569; num_leaves=321; min_data_in_leaf=486; bagging_fraction=0.87; bagging_freq=0; scale_pos_weight=18.7 : y = 0.931 : 257.5 secs : infill_ei
#
# Tue Nov 04 06:57:56 PM 2025 AUC 0.931110329970047
#
# [mbo] 39: num_iterations=2134; learning_rate=0.0137; feature_fraction=0.56; num_leaves=748; min_data_in_leaf=502; bagging_fraction=0.973; bagging_freq=2; scale_pos_weight=18.2 : y = 0.931 : 184.7 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:01:03 PM 2025 AUC 0.929601343992033
#
# [mbo] 40: num_iterations=1940; learning_rate=0.00706; feature_fraction=0.61; num_leaves=583; min_data_in_leaf=506; bagging_fraction=0.989; bagging_freq=0; scale_pos_weight=20.3 : y = 0.93 : 186.5 secs : infill_ei
#
# Tue Nov 04 07:02:39 PM 2025 AUC 0.929704544684324
#
# [mbo] 41: num_iterations=2151; learning_rate=0.016; feature_fraction=0.56; num_leaves=664; min_data_in_leaf=547; bagging_fraction=0.58; bagging_freq=1; scale_pos_weight=1.18 : y = 0.93 : 95.1 secs : infill_ei
#
# Tue Nov 04 07:04:38 PM 2025 AUC 0.929493397816195
#
# [mbo] 42: num_iterations=2526; learning_rate=0.0164; feature_fraction=0.604; num_leaves=709; min_data_in_leaf=463; bagging_fraction=0.914; bagging_freq=3; scale_pos_weight=17.3 : y = 0.929 : 118.0 secs : infill_ei
#
# Tue Nov 04 07:08:01 PM 2025 AUC 0.930231776237501
#
# [mbo] 43: num_iterations=1305; learning_rate=0.00455; feature_fraction=0.614; num_leaves=164; min_data_in_leaf=472; bagging_fraction=0.86; bagging_freq=0; scale_pos_weight=2.17 : y = 0.93 : 202.8 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:09:07 PM 2025 AUC 0.930909844920329
#
# [mbo] 44: num_iterations=389; learning_rate=0.014; feature_fraction=0.537; num_leaves=250; min_data_in_leaf=487; bagging_fraction=0.985; bagging_freq=1; scale_pos_weight=1.02 : y = 0.931 : 65.4 secs : infill_ei
#
# Tue Nov 04 07:14:54 PM 2025 AUC 0.930085358866216
#
# [mbo] 45: num_iterations=2128; learning_rate=0.0045; feature_fraction=0.477; num_leaves=144; min_data_in_leaf=290; bagging_fraction=0.774; bagging_freq=2; scale_pos_weight=26.7 : y = 0.93 : 346.1 secs : infill_ei
#
# Tue Nov 04 07:17:23 PM 2025 AUC 0.927294324372344
#
# [mbo] 46: num_iterations=650; learning_rate=0.00524; feature_fraction=0.56; num_leaves=784; min_data_in_leaf=488; bagging_fraction=0.963; bagging_freq=3; scale_pos_weight=24.4 : y = 0.927 : 148.6 secs : infill_ei
#
# Tue Nov 04 07:22:21 PM 2025 AUC 0.931484401034944
#
# [mbo] 47: num_iterations=2065; learning_rate=0.00474; feature_fraction=0.547; num_leaves=693; min_data_in_leaf=446; bagging_fraction=0.817; bagging_freq=5; scale_pos_weight=15.1 : y = 0.931 : 296.9 secs : infill_ei
#
# Saved the current state after iteration 48 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:29:26 PM 2025 AUC 0.930103807008478
#
# [mbo] 48: num_iterations=1866; learning_rate=0.00467; feature_fraction=0.538; num_leaves=312; min_data_in_leaf=469; bagging_fraction=0.962; bagging_freq=2; scale_pos_weight=15.4 : y = 0.93 : 424.3 secs : infill_ei
#
# Tue Nov 04 07:33:26 PM 2025 AUC 0.930710241443188
#
# [mbo] 49: num_iterations=1716; learning_rate=0.00622; feature_fraction=0.574; num_leaves=764; min_data_in_leaf=474; bagging_fraction=0.862; bagging_freq=6; scale_pos_weight=16.5 : y = 0.931 : 239.8 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:39:25 PM 2025 AUC 0.930552484059621
#
# [mbo] 50: num_iterations=2040; learning_rate=0.00453; feature_fraction=0.556; num_leaves=732; min_data_in_leaf=462; bagging_fraction=0.983; bagging_freq=3; scale_pos_weight=11.7 : y = 0.931 : 358.2 secs : infill_ei
#
# Tue Nov 04 07:43:09 PM 2025 AUC 0.930095208031329
#
# [mbo] 51: num_iterations=2098; learning_rate=0.00483; feature_fraction=0.615; num_leaves=644; min_data_in_leaf=485; bagging_fraction=0.679; bagging_freq=4; scale_pos_weight=16.7 : y = 0.93 : 223.6 secs : infill_ei
#
# Tue Nov 04 07:47:51 PM 2025 AUC 0.930902658026161
#
# [mbo] 52: num_iterations=2774; learning_rate=0.00459; feature_fraction=0.547; num_leaves=975; min_data_in_leaf=427; bagging_fraction=0.893; bagging_freq=0; scale_pos_weight=17.2 : y = 0.931 : 280.8 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:49:56 PM 2025 AUC 0.929919580915827
#
# [mbo] 53: num_iterations=1632; learning_rate=0.0124; feature_fraction=0.575; num_leaves=999; min_data_in_leaf=458; bagging_fraction=0.986; bagging_freq=1; scale_pos_weight=16.8 : y = 0.93 : 124.4 secs : infill_ei
#
# Tue Nov 04 07:55:42 PM 2025 AUC 0.931842809267651
#
# [mbo] 54: num_iterations=2199; learning_rate=0.00469; feature_fraction=0.564; num_leaves=823; min_data_in_leaf=399; bagging_fraction=0.899; bagging_freq=3; scale_pos_weight=16.6 : y = 0.932 : 345.9 secs : infill_ei
#
# Tue Nov 04 08:01:15 PM 2025 AUC 0.930780631746833
#
# [mbo] 55: num_iterations=2111; learning_rate=0.00484; feature_fraction=0.587; num_leaves=333; min_data_in_leaf=425; bagging_fraction=0.928; bagging_freq=5; scale_pos_weight=13.8 : y = 0.931 : 331.9 secs : infill_ei
#
# Saved the current state after iteration 56 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:05:46 PM 2025 AUC 0.931258044335543
#
# [mbo] 56: num_iterations=2168; learning_rate=0.00453; feature_fraction=0.535; num_leaves=722; min_data_in_leaf=429; bagging_fraction=0.857; bagging_freq=1; scale_pos_weight=18.2 : y = 0.931 : 269.8 secs : infill_ei
#
# Tue Nov 04 08:11:20 PM 2025 AUC 0.929679824213732
#
# [mbo] 57: num_iterations=2339; learning_rate=0.00462; feature_fraction=0.577; num_leaves=687; min_data_in_leaf=421; bagging_fraction=0.956; bagging_freq=7; scale_pos_weight=18.1 : y = 0.93 : 334.1 secs : infill_ei
#
# Saved the current state after iteration 58 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:15:35 PM 2025 AUC 0.930097465341106
#
# [mbo] 58: num_iterations=2199; learning_rate=0.00453; feature_fraction=0.583; num_leaves=850; min_data_in_leaf=403; bagging_fraction=0.771; bagging_freq=1; scale_pos_weight=13.7 : y = 0.93 : 254.2 secs : infill_ei
#
# Tue Nov 04 08:21:18 PM 2025 AUC 0.931008678469596
#
# [mbo] 59: num_iterations=2074; learning_rate=0.00495; feature_fraction=0.618; num_leaves=879; min_data_in_leaf=512; bagging_fraction=0.888; bagging_freq=3; scale_pos_weight=17.3 : y = 0.931 : 341.7 secs : infill_ei
#
# Tue Nov 04 08:25:30 PM 2025 AUC 0.930932850927985
#
# [mbo] 60: num_iterations=2021; learning_rate=0.00926; feature_fraction=0.606; num_leaves=695; min_data_in_leaf=338; bagging_fraction=0.897; bagging_freq=4; scale_pos_weight=27.1 : y = 0.931 : 251.6 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:31:01 PM 2025 AUC 0.930730705819354
#
# [mbo] 61: num_iterations=2107; learning_rate=0.00709; feature_fraction=0.564; num_leaves=819; min_data_in_leaf=461; bagging_fraction=0.914; bagging_freq=2; scale_pos_weight=29.3 : y = 0.931 : 330.2 secs : infill_ei
#
# Tue Nov 04 08:38:38 PM 2025 AUC 0.93028957719602
#
# [mbo] 62: num_iterations=2041; learning_rate=0.00475; feature_fraction=0.561; num_leaves=796; min_data_in_leaf=381; bagging_fraction=0.915; bagging_freq=3; scale_pos_weight=18 : y = 0.93 : 456.0 secs : infill_ei
#
# Saved the current state after iteration 63 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:39:38 PM 2025 AUC 0.929753507488094
#
# [mbo] 63: num_iterations=370; learning_rate=0.0276; feature_fraction=0.567; num_leaves=760; min_data_in_leaf=436; bagging_fraction=0.789; bagging_freq=1; scale_pos_weight=1.6 : y = 0.93 : 59.6 secs : infill_ei
#
# Tue Nov 04 08:42:05 PM 2025 AUC 0.930465077705466
#
# [mbo] 64: num_iterations=1310; learning_rate=0.0118; feature_fraction=0.628; num_leaves=845; min_data_in_leaf=523; bagging_fraction=0.95; bagging_freq=4; scale_pos_weight=18.8 : y = 0.93 : 145.6 secs : infill_ei
#
# Tue Nov 04 08:45:33 PM 2025 AUC 0.93017736889034
#
# [mbo] 65: num_iterations=2195; learning_rate=0.00771; feature_fraction=0.575; num_leaves=621; min_data_in_leaf=533; bagging_fraction=0.886; bagging_freq=4; scale_pos_weight=15.3 : y = 0.93 : 207.4 secs : infill_ei
#
# Tue Nov 04 08:46:31 PM 2025 AUC 0.930172251630085
#
# [mbo] 66: num_iterations=363; learning_rate=0.0228; feature_fraction=0.576; num_leaves=969; min_data_in_leaf=550; bagging_fraction=0.603; bagging_freq=0; scale_pos_weight=1.04 : y = 0.93 : 56.6 secs : infill_ei
#
# Tue Nov 04 08:52:32 PM 2025 AUC 0.931316894092706
#
# [mbo] 67: num_iterations=2548; learning_rate=0.00453; feature_fraction=0.581; num_leaves=734; min_data_in_leaf=403; bagging_fraction=0.856; bagging_freq=4; scale_pos_weight=18.8 : y = 0.931 : 360.2 secs : infill_ei
#
# Saved the current state after iteration 68 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:57:57 PM 2025 AUC 0.9302768459038
#
# [mbo] 68: num_iterations=2131; learning_rate=0.00455; feature_fraction=0.596; num_leaves=359; min_data_in_leaf=391; bagging_fraction=0.815; bagging_freq=2; scale_pos_weight=11.3 : y = 0.93 : 324.7 secs : infill_ei
#
# Tue Nov 04 09:02:53 PM 2025 AUC 0.93043646206563
#
# [mbo] 69: num_iterations=2855; learning_rate=0.00597; feature_fraction=0.58; num_leaves=837; min_data_in_leaf=442; bagging_fraction=0.884; bagging_freq=3; scale_pos_weight=9.11 : y = 0.93 : 295.3 secs : infill_ei
#
# Saved the current state after iteration 70 in the file bayesiana.RDATA.
#
# Tue Nov 04 09:08:11 PM 2025 AUC 0.929894492842807
#
# [mbo] 70: num_iterations=2427; learning_rate=0.00459; feature_fraction=0.562; num_leaves=899; min_data_in_leaf=427; bagging_fraction=0.901; bagging_freq=4; scale_pos_weight=19.9 : y = 0.93 : 317.5 secs : infill_ei
#
# Tue Nov 04 09:13:19 PM 2025 AUC 0.929670993622521
#
# [mbo] 71: num_iterations=2971; learning_rate=0.00451; feature_fraction=0.559; num_leaves=660; min_data_in_leaf=399; bagging_fraction=0.945; bagging_freq=0; scale_pos_weight=26.1 : y = 0.93 : 306.3 secs : infill_ei
#
# Saved the current state after iteration 72 in the file bayesiana.RDATA.
#
# Tue Nov 04 09:15:29 PM 2025 AUC 0.929773589430955
#
# [mbo] 72: num_iterations=685; learning_rate=0.0139; feature_fraction=0.593; num_leaves=171; min_data_in_leaf=421; bagging_fraction=0.872; bagging_freq=3; scale_pos_weight=1.11 : y = 0.93 : 129.1 secs : infill_ei
#
# Tue Nov 04 09:17:57 PM 2025 AUC 0.930676758122184
#
# [mbo] 73: num_iterations=1760; learning_rate=0.0123; feature_fraction=0.563; num_leaves=397; min_data_in_leaf=420; bagging_fraction=0.871; bagging_freq=1; scale_pos_weight=27 : y = 0.931 : 147.6 secs : infill_ei
#
# Tue Nov 04 09:22:51 PM 2025 AUC 0.930998649975484
#
# [mbo] 74: num_iterations=2194; learning_rate=0.00519; feature_fraction=0.609; num_leaves=568; min_data_in_leaf=399; bagging_fraction=0.89; bagging_freq=2; scale_pos_weight=8.96 : y = 0.931 : 293.5 secs : infill_ei
#
# Tue Nov 04 09:24:35 PM 2025 AUC 0.930624571069164
#
# [mbo] 75: num_iterations=2139; learning_rate=0.0127; feature_fraction=0.631; num_leaves=174; min_data_in_leaf=463; bagging_fraction=0.924; bagging_freq=1; scale_pos_weight=21.3 : y = 0.931 : 103.0 secs : infill_ei
#
# Saved the current state after iteration 76 in the file bayesiana.RDATA.
#
# Tue Nov 04 09:27:24 PM 2025 AUC 0.9298606024539
#
# [mbo] 76: num_iterations=2238; learning_rate=0.00709; feature_fraction=0.584; num_leaves=953; min_data_in_leaf=490; bagging_fraction=0.885; bagging_freq=0; scale_pos_weight=22.9 : y = 0.93 : 167.1 secs : infill_ei
#
# Tue Nov 04 09:33:21 PM 2025 AUC 0.930639171388476
#
# [mbo] 77: num_iterations=2573; learning_rate=0.0046; feature_fraction=0.611; num_leaves=761; min_data_in_leaf=419; bagging_fraction=0.932; bagging_freq=2; scale_pos_weight=15.9 : y = 0.931 : 356.9 secs : infill_ei
#
# Tue Nov 04 09:39:22 PM 2025 AUC 0.930366817037796
#
# [mbo] 78: num_iterations=2675; learning_rate=0.0046; feature_fraction=0.496; num_leaves=445; min_data_in_leaf=376; bagging_fraction=0.812; bagging_freq=3; scale_pos_weight=17.1 : y = 0.93 : 359.5 secs : infill_ei
#
# Saved the current state after iteration 79 in the file bayesiana.RDATA.
#
# Tue Nov 04 09:41:15 PM 2025 AUC 0.930113973187236
#
# [mbo] 79: num_iterations=653; learning_rate=0.00763; feature_fraction=0.546; num_leaves=164; min_data_in_leaf=475; bagging_fraction=0.819; bagging_freq=0; scale_pos_weight=1 : y = 0.93 : 112.3 secs : infill_ei
#
# Tue Nov 04 09:44:16 PM 2025 AUC 0.929418584639111
#
# [mbo] 80: num_iterations=2208; learning_rate=0.0114; feature_fraction=0.541; num_leaves=656; min_data_in_leaf=334; bagging_fraction=0.894; bagging_freq=4; scale_pos_weight=27.3 : y = 0.929 : 179.7 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "bagging_fraction" "bagging_freq"     "scale_pos_weight"
#  [9] "y"                "dob"              "eol"              "error.message"
# [13] "exec.time"        "ei"               "error.model"      "train.time"
# [17] "prop.type"        "propose.time"     "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           2199   0.004689911        0.5638927        823              399
#    bagging_fraction bagging_freq scale_pos_weight
#               <num>        <int>            <num>
# 1:        0.8992532            3         16.56248
# [1] 0.9318428

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 700001
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.8992532
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 16.56248
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2199
#
# $early_stopping_rounds
# [1] 200
#
# $learning_rate
# [1] 0.004689911
#
# $feature_fraction
# [1] 0.5638927
#
# $num_leaves
# [1] 823
#
# $min_data_in_leaf
# [1] 399
#
# $bagging_freq
# [1] 3

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

# Entrenamiento Final del Modelo

# 1. CORRECCIÓN DE ERROR 1: Desactivo el Early Stopping para el modelo final
param_normalizado$early_stopping_rounds <- NULL

modelo_final <- lgb.train(
  params= param_normalizado,
  data= dtrain,
  verbose= -1
)

# *****************************************************************
# 2. CORRECCIÓN DE ERROR 2: Se define 'dfuture' ANTES de usarlo
# aplico el modelo a los datos sin clase (ESTA LÍNEA DEBE IR PRIMERO)
dfuture <- dataset[foto_mes == 202109]

# Se agrega el campo clase_ternaria (a la cual se le asigna 0)
# (ESTA LÍNEA DEBE IR SEGUNDO)
dfuture[, clase_ternaria := 0 ]
# *****************************************************************

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 09:55:56 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
